# %% [markdown]
# # PubChem

# %% [markdown]
# In this notebook we took structures from PDBbind core-set to find UniProt IDs for their corresponding protein. Next we mapped UniProt IDs to Gene IDs using [UniProt ID mapping](http://www.uniprot.org/uploadlists/) and found all matching PubChem Assay IDs. After downloading data from [PubChem](https://pubchem.ncbi.nlm.nih.gov/), we cleaned it and compared to data from [ChEMBL](https://www.ebi.ac.uk/chembl/). Finally we saved the data to csv.

# %%
import os
import re
import requests
import pandas as pd
from lxml import etree
from tqdm import tqdm_notebook
from contextlib import redirect_stderr

import PubChem as pubchem

# %% [markdown]
# ## Loading pdbbind core-set information

# %% [markdown]
# #### Cluster ID

# %%
f = './refined-set/index/INDEX_core_cluster.2016'
clusters = pd.read_csv(f, sep='\s+', usecols=[0, 5], 
                       names=['pdb_id', 'cluster_id'], comment='#')
clusters.head()
# Out:
#   pdb_id  cluster_id
# 0   1ps3           3
# 1   3dx1           3
# 2   3d4z           3
# 3   3dx2           3
# 4   3ejr           3

# %% [markdown]
# #### UniProt ID

# %%
f = './refined-set/index/INDEX_general_PL_name.2016'
uniprot = pd.read_csv(f, sep='\s+', usecols=[0, 2], 
                      names=['pdb_id', 'uniprot_id'], comment='#')
uniprot.head()
# Out:
#   pdb_id uniprot_id
# 0   3eql     Q9Z9H6
# 1   1zyr     Q5SHR6
# 2   3dxj     Q5SHR6
# 3   4zh4     P0A7Z4
# 4   4zh3     P0A7Z4

# %% [markdown]
# #### Merge

# %%
data_pdb = clusters.merge(uniprot, on='pdb_id')
data_pdb.head()
# Out:
#   pdb_id  cluster_id uniprot_id
# 0   1ps3           3     Q24451
# 1   3dx1           3     Q24451
# 2   3d4z           3     Q24451
# 3   3dx2           3     Q24451
# 4   3ejr           3     Q24451

# %% [markdown]
# ## ID mapping

# %% [markdown]
# #### From UniProt ID to Gene ID

# %%
# all uniprot IDs 
uniprot_ids = set(data_pdb['uniprot_id'].tolist())

# %%
text_file = open('UniProt_IDs.txt', 'w')
tmp = re.sub(r'[,\'{}]', '', str(uniprot_ids))
text_file.write(tmp)
text_file.close()

# %% [markdown]
# For mapping I used http://www.uniprot.org/uploadlists/.

# %%
mapping_gid = pd.read_csv('./GeneName.txt', sep='\t')
mapping_gid.head()
# Out:
#      From     To
# 0  P00519     25
# 1  P15207  24208
# 2  P19491  29627
# 3  P11309   5292
# 4  Q9Y233  10846

# %%
gene_ids = set(mapping_gid['To'])

# %% [markdown]
# ## Download data
# #### For every Gene ID find matching Assay ID(s) and then for every Assay ID download csv from PubChem

# %%
# path to store information
directory = './aid_files/'
os.system('mkdir -p %s' % directory)
# Out:
# 0

# %%
for gene_id in gene_ids:

    aids = pubchem.get_AIDs(gene_id)
    
    if aids[0] != 'Status:':
        for aid in aids:
            pubchem.download_aid_csv(aid, directory)

# %%
aid_list = []
gen_list = []

for gene_id in gene_ids:

    aids = pubchem.get_AIDs(gene_id)
    if aids[0] != 'Status:':
        aid_list += aids
        gen_list += [gene_id]*len(aids)
    
gen_aid = pd.DataFrame({'aid': aid_list, 'gen': gen_list})
gen_aid.head()
# Out:
#       aid   gen
# 0    1433  3716
# 1    1982  3716
# 2  256646  3716
# 3  277462  3716
# 4  339778  3716

# %% [markdown]
# ### Example

# %%
pd.read_csv('./aid_files/1141064.csv', index_col=0)
# Out:
#                                 PUBCHEM_SID  PUBCHEM_CID  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                             NaN          NaN
# RESULT_DESCR                            NaN          NaN
# RESULT_UNIT                             NaN          NaN
# RESULT_IS_ACTIVE_CONCENTRATION          NaN          NaN
# 1                               194146212.0   56684144.0
# 2                               242634058.0   57381960.0
#
#                                PUBCHEM_ACTIVITY_OUTCOME  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                         NaN
# RESULT_DESCR                                        NaN
# RESULT_UNIT                                         NaN
# RESULT_IS_ACTIVE_CONCENTRATION                      NaN
# 1                                                Active
# 2                                           Unspecified
#
#                                 PUBCHEM_ACTIVITY_SCORE  PUBCHEM_ACTIVITY_URL  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                        NaN                   NaN
# RESULT_DESCR                                       NaN                   NaN
# RESULT_UNIT                                        NaN                   NaN
# RESULT_IS_ACTIVE_CONCENTRATION                     NaN                   NaN
# 1                                                  NaN                   NaN
# 2                                                  NaN                   NaN
#
#                                 PUBCHEM_ASSAYDATA_COMMENT  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                           NaN
# RESULT_DESCR                                          NaN
# RESULT_UNIT                                           NaN
# RESULT_IS_ACTIVE_CONCENTRATION                        NaN
# 1                                                     NaN
# 2                                                     NaN
#
#                                                        IC50  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                           FLOAT
# RESULT_DESCR                    IC50 PubChem standard value
# RESULT_UNIT                                      MICROMOLAR
# RESULT_IS_ACTIVE_CONCENTRATION                         TRUE
# 1                                                       4.1
# 2                                                       117
#
#                                                          SEI  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                            FLOAT
# RESULT_DESCR                    Surface Efficiency Index(nM)
# RESULT_UNIT                                              NaN
# RESULT_IS_ACTIVE_CONCENTRATION                           NaN
# 1                                                       4.43
# 2                                                        NaN
#
#                                                          BEI  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                            FLOAT
# RESULT_DESCR                    Binding Efficiency Index(nM)
# RESULT_UNIT                                              NaN
# RESULT_IS_ACTIVE_CONCENTRATION                           NaN
# 1                                                      13.13
# 2                                                        NaN
#
#                                                LE  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                 FLOAT
# RESULT_DESCR                    Ligand Efficiency
# RESULT_UNIT                                   NaN
# RESULT_IS_ACTIVE_CONCENTRATION                NaN
# 1                                            0.25
# 2                                             NaN
#
#                                                          LLE  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                            FLOAT
# RESULT_DESCR                    Lipophilic Ligand Efficiency
# RESULT_UNIT                                              NaN
# RESULT_IS_ACTIVE_CONCENTRATION                           NaN
# 1                                                       5.23
# 2                                                        NaN
#
#                                 IC50 activity comment  IC50 standard flag  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                    STRING             INTEGER
# RESULT_DESCR                    IC50 activity comment  IC50 standard flag
# RESULT_UNIT                                       NaN                 NaN
# RESULT_IS_ACTIVE_CONCENTRATION                    NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
#
#                                 IC50 qualifier  IC50 published value  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                             STRING                 FLOAT
# RESULT_DESCR                    IC50 qualifier  IC50 published value
# RESULT_UNIT                                NaN            MICROMOLAR
# RESULT_IS_ACTIVE_CONCENTRATION             NaN                   NaN
# 1                                            =                   4.1
# 2                                            =                   117
#
#                                 IC50 standard value     IC50 data validity
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                   FLOAT                 STRING
# RESULT_DESCR                    IC50 standard value     IC50 data validity
# RESULT_UNIT                               NANOMOLAR                    NaN
# RESULT_IS_ACTIVE_CONCENTRATION                  NaN                    NaN
# 1                                              4100                    NaN
# 2                                            117000  Outside typical range

# %% [markdown]
# ## Find csv with good bioactivity types

# %%
good_aids = []
activity = []

# redirect stderr to file
with open('stderr.log', 'w') as stderr, redirect_stderr(stderr):
    for gene_id in gene_ids:

        aids = pubchem.get_AIDs(gene_id)

        for aid in aids:

            try:
                data = pd.read_csv('./aid_files/%s.csv' % aid, index_col=0)
            except:
                continue

            for col in data:
                if re.search(r'(IC50)', col):
                #if re.search(r'[(EC50)(IC50)(Inhibition)]', col):  # (Activity)(Ka)(Kd)(Ki)(Km)
                    activity.append(col)
                    good_aids.append(aid)
                    #break

# %%
good_aids = list(set(good_aids))
len(good_aids)
# Out:
# 2771

# %%
set(activity)
# Out:
# {'Activity At IC50',
#  'Ba/F3 Cytotoxicity (IC50) ',
#  'High Concentration (5 x IC50)',
#  'I/IC50 activity comment',
#  'I/IC50 published value',
#  'I/IC50 qualifier',
#  'I/IC50 standard flag',
#  'I/IC50 standard value',
#  'IC50',
#  'IC50 Binding Efficiency Index(nM)',
#  'IC50 Binding Efficiency Index(nM).1',
#  'IC50 Hill slope',
#  'IC50 Ligand Efficiency',
#  'IC50 Ligand Efficiency.1',
#  'IC50 Lipophilic Ligand Efficiency',
#  'IC50 Lipophilic Ligand Efficiency.1',
#  'IC50 R-squared',
#  'IC50 Surface Efficiency Index(nM)',
#  'IC50 Surface Efficiency Index(nM).1',
#  'IC50 activity comment',
#  'IC50 activity comment.1',
#  'IC50 binding domains',
#  'IC50 binding domains.1',
#  'IC50 blank mean',
#  'IC50 blank percent CV',
#  'IC50 blank standard deviation',
#  'IC50 control mean',
#  'IC50 control percent CV',
#  'IC50 control standard deviation',
#  'IC50 data validity',
#  'IC50 data validity.1',
#  'IC50 max concentration',
#  'IC50 min concentration',
#  'IC50 number of blank wells',
#  'IC50 number of control wells',
#  'IC50 percent activity at max concentration',
#  'IC50 percent activity at min concentration',
#  'IC50 plate Z-factor',
#  'IC50 published value',
#  'IC50 published value.1',
#  'IC50 qualifier',
#  'IC50 qualifier.1',
#  'IC50 signal at 0.00152 microM',
#  'IC50 signal at 0.00305 microM',
#  'IC50 signal at 0.00610 microM',
#  'IC50 signal at 0.01221 microM',
#  'IC50 signal at 0.02441 microM',
#  'IC50 signal at 0.04883 microM',
#  'IC50 signal at 0.09766 microM',
#  'IC50 signal at 0.19531 microM',
#  'IC50 signal at 0.39063 microM',
#  'IC50 signal at 0.78125 microM',
#  'IC50 signal at 1.5625 microM',
#  'IC50 signal at 12.5 microM',
#  'IC50 signal at 25 microM',
#  'IC50 signal at 3.125 microM',
#  'IC50 signal at 50 microM',
#  'IC50 signal at 6.25 microM',
#  'IC50 signal-background ratio',
#  'IC50 standard flag',
#  'IC50 standard flag.1',
#  'IC50 standard value',
#  'IC50 standard value.1',
#  'JAK2V617F Inhibition (IC50)',
#  'Log IC50 activity comment',
#  'Log IC50 published value',
#  'Log IC50 qualifier',
#  'Log IC50 standard flag',
#  'Log IC50 standard value',
#  'LogIC50',
#  'Low Concentration (IC50 / 2)',
#  'Number of IC50 determinations',
#  'Qualifier [IC50]',
#  'Ratio IC50 activity comment',
#  'Ratio IC50 activity comment.1',
#  'Ratio IC50 published value',
#  'Ratio IC50 published value.1',
#  'Ratio IC50 qualifier',
#  'Ratio IC50 qualifier.1',
#  'Ratio IC50 standard flag',
#  'Ratio IC50 standard flag.1',
#  'Ratio IC50 standard value',
#  'Ratio IC50 standard value.1',
#  'irf1 Inhibition [Ba/F3 cells] (IC50) ',
#  'irf1 Inhibition [HEL cells] (IC50) ',
#  'pIC50',
#  'pIC50 activity comment',
#  'pIC50 binding domains',
#  'pIC50 data validity',
#  'pIC50 published value',
#  'pIC50 qualifier',
#  'pIC50 standard flag',
#  'pIC50 standard value'}

# %%
data = pd.read_csv('./aid_files/%s.csv' % good_aids[0], index_col=0)
data
# Out:
#                                 PUBCHEM_SID  PUBCHEM_CID  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                             NaN          NaN
# RESULT_DESCR                            NaN          NaN
# RESULT_UNIT                             NaN          NaN
# RESULT_IS_ACTIVE_CONCENTRATION          NaN          NaN
# 1                               242637107.0   53389651.0
#
#                                PUBCHEM_ACTIVITY_OUTCOME  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                         NaN
# RESULT_DESCR                                        NaN
# RESULT_UNIT                                         NaN
# RESULT_IS_ACTIVE_CONCENTRATION                      NaN
# 1                                           Unspecified
#
#                                 PUBCHEM_ACTIVITY_SCORE  PUBCHEM_ACTIVITY_URL  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                        NaN                   NaN
# RESULT_DESCR                                       NaN                   NaN
# RESULT_UNIT                                        NaN                   NaN
# RESULT_IS_ACTIVE_CONCENTRATION                     NaN                   NaN
# 1                                                  NaN                   NaN
#
#                                 PUBCHEM_ASSAYDATA_COMMENT  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                           NaN
# RESULT_DESCR                                          NaN
# RESULT_UNIT                                           NaN
# RESULT_IS_ACTIVE_CONCENTRATION                        NaN
# 1                                                     NaN
#
#                                                        IC50  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                           FLOAT
# RESULT_DESCR                    IC50 PubChem standard value
# RESULT_UNIT                                      MICROMOLAR
# RESULT_IS_ACTIVE_CONCENTRATION                         TRUE
# 1                                                        10
#
#                                 IC50 activity comment  IC50 standard flag  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                    STRING             INTEGER
# RESULT_DESCR                    IC50 activity comment  IC50 standard flag
# RESULT_UNIT                                       NaN                 NaN
# RESULT_IS_ACTIVE_CONCENTRATION                    NaN                 NaN
# 1                                                 NaN                 NaN
#
#                                 IC50 qualifier  IC50 published value  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                             STRING                 FLOAT
# RESULT_DESCR                    IC50 qualifier  IC50 published value
# RESULT_UNIT                                NaN            MICROMOLAR
# RESULT_IS_ACTIVE_CONCENTRATION             NaN                   NaN
# 1                                            >                    10
#
#                                 IC50 standard value
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                   FLOAT
# RESULT_DESCR                    IC50 standard value
# RESULT_UNIT                               NANOMOLAR
# RESULT_IS_ACTIVE_CONCENTRATION                  NaN
# 1                                             10000

# %%
data[[x for x in data.columns if x in activity]]
# Out:
#                                                        IC50  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                           FLOAT
# RESULT_DESCR                    IC50 PubChem standard value
# RESULT_UNIT                                      MICROMOLAR
# RESULT_IS_ACTIVE_CONCENTRATION                         TRUE
# 1                                                        10
#
#                                 IC50 activity comment  IC50 standard flag  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                    STRING             INTEGER
# RESULT_DESCR                    IC50 activity comment  IC50 standard flag
# RESULT_UNIT                                       NaN                 NaN
# RESULT_IS_ACTIVE_CONCENTRATION                    NaN                 NaN
# 1                                                 NaN                 NaN
#
#                                 IC50 qualifier  IC50 published value  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                             STRING                 FLOAT
# RESULT_DESCR                    IC50 qualifier  IC50 published value
# RESULT_UNIT                                NaN            MICROMOLAR
# RESULT_IS_ACTIVE_CONCENTRATION             NaN                   NaN
# 1                                            >                    10
#
#                                 IC50 standard value
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                                   FLOAT
# RESULT_DESCR                    IC50 standard value
# RESULT_UNIT                               NANOMOLAR
# RESULT_IS_ACTIVE_CONCENTRATION                  NaN
# 1                                             10000

# %%
for aid in good_aids:
        
        data = pd.read_csv('./aid_files/%s.csv' % aid, index_col=0)
                
        if 'PUBCHEM_SID' not in data.columns:
            print(aid, col)

# %%
data = pd.read_csv('./aid_files/%s.csv' % '721825', index_col=0)
data[[x for x in data.columns if x in activity]]
# Out:
#                     IC50 activity comment  IC50 standard flag  IC50 qualifier  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                        STRING             INTEGER          STRING
# RESULT_DESCR        IC50 activity comment  IC50 standard flag  IC50 qualifier
# RESULT_UNIT                           NaN                 NaN             NaN
# 1                                     NaN                 NaN               =
#
#                     IC50 published value  IC50 standard value  \
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                        FLOAT                FLOAT
# RESULT_DESCR        IC50 published value  IC50 standard value
# RESULT_UNIT                      ug ml-1              ug.mL-1
# 1                                   92.7                 92.7
#
#                        IC50 data validity  IC50 binding domains
# PUBCHEM_RESULT_TAG
# RESULT_TYPE                        STRING                STRING
# RESULT_DESCR           IC50 data validity  IC50 binding domains
# RESULT_UNIT                           NaN                   NaN
# 1                   Outside typical range                   NaN

# %%
# redirect stderr to file
with open('stderr.log', 'w') as stderr, redirect_stderr(stderr):
    for gene_id in list(gene_ids):

        aids = list(gen_aid.loc[gen_aid['gen'] == gene_id]['aid'])
        data = pubchem.gene_id_to_data_frame(gene_id, aids)
        data.to_csv('./pubchem/pubchem_%s.csv' % gene_id, index=False)

# %%
pd.read_csv('./pubchem/pubchem_100008972.csv')
# Out:
#    bioactivity    gene_id  pubchem_aid  pubchem_sid       value
# 0         IC50  100008972       260787  103178995.0    114.0000
# 1         IC50  100008972       266475  103178995.0    114.0000
# 2         IC50  100008972       270947  103485311.0      1.2100
# 3         IC50  100008972       270948  103485311.0      0.7600
# 4         IC50  100008972       404873  103165295.0     43.0000
# 5         IC50  100008972       408492  103641450.0  11700.0000
# 6         IC50  100008972       426720  103684498.0  10000.0000
# 7         IC50  100008972       427071  103178995.0    283.0000
# 8         IC50  100008972       427132  103625236.0         NaN
# 9         IC50  100008972       436293  103178995.0     83.1000
# 10        IC50  100008972       443935  103178995.0     74.9000
# 11        IC50  100008972       452609  103544015.0     23.9000
# 12        IC50  100008972       454714  103719146.0    630.0000
# 13        IC50  100008972       459831  103728361.0    500.0000
# 14        IC50  100008972       469220  103178995.0     75.3000
# 15        IC50  100008972       537598  123085762.0    180.0000
# 16        IC50  100008972       549503  103178995.0     75.3000
# 17        IC50  100008972       603224  103165295.0     42.6579
# 18        IC50  100008972       612673  103362169.0      7.5000
# 19        IC50  100008972       614129  104234206.0         NaN
# 20        IC50  100008972       640379  103178995.0     75.3000
# 21        IC50  100008972       661299  103340191.0      0.0016
# 22        IC50  100008972       661300  103376375.0      4.8000
# 23        IC50  100008972       661302  103178995.0    100.0000
# 24        IC50  100008972       667422  104234206.0         NaN
# 25        IC50  100008972      1185534  103178995.0    648.0000
